# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishita-Jinturkar/EDA/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Liver%20Data.csv"

df = pd.read_csv(url)
print(df.head())
# Out:
#    Age of the patient Gender of the patient  Total Bilirubin  \
# 0                65.0                Female              0.7
# 1                62.0                  Male             10.9
# 2                62.0                  Male              7.3
# 3                58.0                  Male              1.0
# 4                72.0                  Male              3.9
#
#    Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0               0.1                          187.0
# 1               5.5                          699.0
# 2               4.1                          490.0
# 3               0.4                          182.0
# 4               2.0                          195.0
#
#     Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                            16.0                             18.0
# 1                            64.0                            100.0
# 2                            60.0                             68.0
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30686    False
# 30687     True
# 30688    False
# 30689    False
# 30690     True
# Length: 30691, dtype: bool

# %%
df=df.drop_duplicates()

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29974    False
# 29976    False
# 30686    False
# 30688    False
# 30689    False
# Length: 19368, dtype: bool

# %%
df.isnull()
# Out:
#        Age of the patient  Gender of the patient  Total Bilirubin  \
# 0                   False                  False            False
# 1                   False                  False            False
# 2                   False                  False            False
# 3                   False                  False            False
# 4                   False                  False            False
# ...                   ...                    ...              ...
# 29974               False                  False            False
# 29976               False                  False            False
# 30686               False                  False            False
# 30688               False                  False            False
# 30689               False                  False            False
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0                 False                          False
# 1                 False                          False
# ...

# %%
df.isnull().sum()
# Out:
# Age of the patient                        1
# Gender of the patient                   796
# Total Bilirubin                         557
# Direct Bilirubin                        490
#  Alkphos Alkaline Phosphotase           694
#  Sgpt Alamine Aminotransferase          459
# Sgot Aspartate Aminotransferase         393
# Total Protiens                          370
#  ALB Albumin                            413
# A/G Ratio Albumin and Globulin Ratio    436
# Result                                    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 4609

# %%
df.notnull().sum()
# Out:
# Age of the patient                      19367
# Gender of the patient                   18572
# Total Bilirubin                         18811
# Direct Bilirubin                        18878
#  Alkphos Alkaline Phosphotase           18674
#  Sgpt Alamine Aminotransferase          18909
# Sgot Aspartate Aminotransferase         18975
# Total Protiens                          18998
#  ALB Albumin                            18955
# A/G Ratio Albumin and Globulin Ratio    18932
# Result                                  19368
# dtype: int64

# %%
df.dropna(how='all')
# Out:
#        Age of the patient Gender of the patient  Total Bilirubin  \
# 0                    65.0                Female              0.7
# 1                    62.0                  Male             10.9
# 2                    62.0                  Male              7.3
# 3                    58.0                  Male              1.0
# 4                    72.0                  Male              3.9
# ...                   ...                   ...              ...
# 29974                58.0                  Male              2.9
# 29976                28.0                  Male              1.9
# 30686                50.0                  Male              2.2
# 30688                54.0                  Male              6.8
# 30689                48.0                Female              1.9
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0                   0.1                          187.0
# 1                   5.5                          699.0
# ...

# %%
df.dropna(how='all' ,axis=1)
# Out:
#        Age of the patient Gender of the patient  Total Bilirubin  \
# 0                    65.0                Female              0.7
# 1                    62.0                  Male             10.9
# 2                    62.0                  Male              7.3
# 3                    58.0                  Male              1.0
# 4                    72.0                  Male              3.9
# ...                   ...                   ...              ...
# 29974                58.0                  Male              2.9
# 29976                28.0                  Male              1.9
# 30686                50.0                  Male              2.2
# 30688                54.0                  Male              6.8
# 30689                48.0                Female              1.9
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0                   0.1                          187.0
# 1                   5.5                          699.0
# ...

# %%
print(df.columns)
df.columns = df.columns.str.strip()
# Out:
# Index(['Age of the patient', 'Gender of the patient', 'Total Bilirubin',
#        'Direct Bilirubin', ' Alkphos Alkaline Phosphotase',
#        ' Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase',
#        'Total Protiens', ' ALB Albumin',
#        'A/G Ratio Albumin and Globulin Ratio', 'Result'],
#       dtype='object')

# %%
# Handling missing values by replacing with column means
age_mean = df['Age of the patient'].mean()
df['Age of the patient'].fillna(age_mean, inplace=True)

total_bilirubin_mean = df['Total Bilirubin'].mean()
df['Total Bilirubin'].fillna(total_bilirubin_mean, inplace=True)

direct_bilirubin_mean = df['Direct Bilirubin'].mean()
df['Direct Bilirubin'].fillna(direct_bilirubin_mean, inplace=True)

alkphos_mean = df['Alkphos Alkaline Phosphotase'].mean()
df['Alkphos Alkaline Phosphotase'].fillna(alkphos_mean, inplace=True)

sgpt_mean = df['Sgpt Alamine Aminotransferase'].mean()
df['Sgpt Alamine Aminotransferase'].fillna(sgpt_mean, inplace=True)

sgot_mean = df['Sgot Aspartate Aminotransferase'].mean()
df['Sgot Aspartate Aminotransferase'].fillna(sgot_mean, inplace=True)

total_proteins_mean = df['Total Protiens'].mean()
df['Total Protiens'].fillna(total_proteins_mean, inplace=True)

albumin_mean = df['ALB Albumin'].mean()
df['ALB Albumin'].fillna(albumin_mean, inplace=True)

ag_ratio_mean = df['A/G Ratio Albumin and Globulin Ratio'].mean()
df['A/G Ratio Albumin and Globulin Ratio'].fillna(ag_ratio_mean, inplace=True)
# Out:
# <ipython-input-12-4f363e45f513>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age of the patient'].fillna(age_mean, inplace=True)
# <ipython-input-12-4f363e45f513>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
import numpy as np
df[np.abs(df['Alkphos Alkaline Phosphotase'])>700]
df[np.abs(df['Sgot Aspartate Aminotransferase'])>75]
# Out:
#        Age of the patient Gender of the patient  Total Bilirubin  \
# 1                    62.0                  Male             10.9
# 16                   38.0                  Male              1.8
# 18                   40.0                Female              0.9
# 21                   51.0                  Male              2.9
# 25                   34.0                  Male              4.1
# ...                   ...                   ...              ...
# 29861                53.0                  Male             26.3
# 29869                47.0                Female              3.5
# 29875                35.0                  Male              1.4
# 29878                49.0                   NaN             15.8
# 29895                61.0                Female             10.2
#
#        Direct Bilirubin  Alkphos Alkaline Phosphotase  \
# 1                   5.5                         699.0
# 16                  0.8                         342.0
# ...

# %%
mean = df["Age of the patient"].mean()
median =df["Age of the patient"].median()
mode = df["Age of the patient"].mode()
print(mean , median, mode)
# Out:
# 43.80998605875975 45.0 0    45.0
# Name: Age of the patient, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.set(style="whitegrid")

# %% [markdown]
# Univariate Analysis

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Total Bilirubin'], kde=True, color='skyblue')
plt.title('Distribution of Total Bilirubin')
plt.show()

# 2. Boxplot for Total Bilirubin
plt.figure(figsize=(10, 6))
sns.boxplot(y=df['Total Bilirubin'], color='lightgreen')
plt.title('Boxplot of Total Bilirubin')
plt.show()

# 3. Violin Plot for Total Bilirubin
plt.figure(figsize=(10, 6))
sns.violinplot(y=df['Total Bilirubin'], color='lightcoral')
plt.title('Violin Plot of Total Bilirubin')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# 4. Scatterplot between Age of the patient and Total Bilirubin
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Age of the patient'], y=df['Total Bilirubin'], hue=df['Gender of the patient'], palette='cool')
plt.title('Scatterplot: Age vs Total Bilirubin')
plt.show()

# 5. Violin Plot between Gender and Total Bilirubin
plt.figure(figsize=(10, 6))
sns.violinplot(x=df['Gender of the patient'], y=df['Total Bilirubin'], palette='muted')
plt.title('Violin Plot: Gender vs Total Bilirubin')
plt.show()
# Out:
# <ipython-input-21-2f29851b9095>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df['Gender of the patient'], y=df['Total Bilirubin'], palette='muted')

# %% [markdown]
# # Multivariate Analysis

# %%
# 7. Pairplot (Numerical Variables Only)
plt.figure(figsize=(12, 8))
sns.pairplot(df, diag_kind="kde", hue="Gender of the patient", markers=["o", "s"])
plt.show()

# 8. 3D Scatterplot (Age, Total Bilirubin, Alkphos Alkaline Phosphotase)
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['Age of the patient'], df['Total Bilirubin'], df['Alkphos Alkaline Phosphotase'],
           c=np.random.rand(len(df)), cmap='plasma')

ax.set_xlabel('Age of the patient')
ax.set_ylabel('Total Bilirubin')
ax.set_zlabel('Alkphos Alkaline Phosphotase')
plt.title('3D Scatterplot: Age, Total Bilirubin, Alkphos Alkaline Phosphotase')
plt.show()

# %%
numeric_columns = ['Age of the patient', 'Total Bilirubin', 'Direct Bilirubin',
                   'Alkphos Alkaline Phosphotase', 'Sgpt Alamine Aminotransferase',
                   'Sgot Aspartate Aminotransferase', 'Total Protiens', 'ALB Albumin',
                   'A/G Ratio Albumin and Globulin Ratio']

for col in numeric_columns:
    print(f"--- {col} ---")
    print(f"Mean: {df[col].mean()}")
    print(f"Median: {df[col].median()}")
    print(f"Mode: {df[col].mode().values[0]}")
    print(f"Standard Deviation: {df[col].std()}")
    print(f"Range: {df[col].max() - df[col].min()}")
    print(f"Interquartile Range: {df[col].quantile(0.75) - df[col].quantile(0.25)}\n")

for col in numeric_columns:
    plt.hist(df[col], bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

for col in numeric_columns:
    plt.boxplot(df[col].dropna())
    plt.title(f'Box Plot of {col}')
    plt.ylabel(col)
    plt.show()
selected_col = 'Total Bilirubin'
sorted_values = np.sort(df[selected_col])
cumulative_frequency = np.arange(1, len(sorted_values) + 1) / len(sorted_values)

plt.plot(sorted_values, cumulative_frequency, marker='o')
plt.title(f'Ogive of {selected_col}')
plt.xlabel(selected_col)
plt.ylabel('Cumulative Frequency')
plt.show()
# Out:
# --- Age of the patient ---
# Mean: 43.80998605875975
# Median: 45.0
# Mode: 45.0
# Standard Deviation: 16.454563473248815
# Range: 86.0
# Interquartile Range: 23.0
#
# --- Total Bilirubin ---
# Mean: 3.31576737015576
# Median: 1.0
# Mode: 0.8
# Standard Deviation: 6.023320642541394
# Range: 74.6
# Interquartile Range: 1.9999999999999998
#
# --- Direct Bilirubin ---
# Mean: 1.5156372497086557
# Median: 0.3
# Mode: 0.2
# Standard Deviation: 2.8271509985898695
# Range: 19.599999999999998
# Interquartile Range: 1.2
#
# --- Alkphos Alkaline Phosphotase ---
# Mean: 289.40741137410305
# Median: 214.0
# Mode: 289.40741137410305
# Standard Deviation: 235.39287646355186
# Range: 2047.0
# Interquartile Range: 116.0
#
# --- Sgpt Alamine Aminotransferase ---
# Mean: 80.59876249405043
# Median: 36.0
# Mode: 25.0
# Standard Deviation: 178.97530816879998
# Range: 1990.0
# Interquartile Range: 41.0
#
# --- Sgot Aspartate Aminotransferase ---
# Mean: 110.7906719367589
# Median: 43.0
# Mode: 23.0
# ...

# %%
df.columns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
X = df.iloc[:, [3, 4]].values
wcss = []
for i in range(1, 11):
 kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
 kmeans.fit(X)
 wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red',
label='Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue',
label='Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100,
c='green', label='Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=100, c='cyan',
label='Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s=100,
c='magenta', label='Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,
1], s=300, c='yellow', label='Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(15, 6))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()
plt.figure(figsize=(15, 6))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.hlines(y=190, xmin=0, xmax=2000, lw=3, linestyles='--')
plt.text(x=900, y=220, s='Horizontal line crossing 5 vertical lines',
fontsize=20)
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
X = df.iloc[:, [3, 4]].values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c='purple', s=50, label='PCA projection')
plt.title('PCA of Customer Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)
plt.show()
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X_pca)
plt.figure(figsize=(8,6))
plt.scatter(X_pca[y_kmeans == 0, 0], X_pca[y_kmeans == 0, 1], s=100,
c='red', label='Cluster 1')
plt.scatter(X_pca[y_kmeans == 1, 0], X_pca[y_kmeans == 1, 1], s=100,
c='blue', label='Cluster 2')
plt.scatter(X_pca[y_kmeans == 2, 0], X_pca[y_kmeans == 2, 1], s=100,
c='green', label='Cluster 3')
plt.scatter(X_pca[y_kmeans == 3, 0], X_pca[y_kmeans == 3, 1], s=100,
c='cyan', label='Cluster 4')
plt.scatter(X_pca[y_kmeans == 4, 0], X_pca[y_kmeans == 4, 1], s=100,
c='magenta', label='Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,
1], s=300, c='yellow', label='Centroids')
plt.title('K-Means Clusters in PCA Space')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Explained Variance ratio (to understand how much variance is explained by the 2 principal components)
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.6082411 0.3917589]

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

numeric_cols = df.select_dtypes(include=['number'])
print("Numeric Columns in Dataset:")
print(numeric_cols.columns)

plt.figure(figsize=(12, 8))
sns.heatmap(numeric_cols.corr(), annot=True, cmap="RdYlGn", square=True)
plt.title("Correlation Heatmap")
plt.show()
sns.lmplot(x='Total Bilirubin', y='Result', data=df, height=6, aspect=1.5)
plt.title("Simple Linear Regression: Total Bilirubin vs Result")
plt.show()

X_simple = df[['Total Bilirubin']]
y_simple = df[['Result']]


X_train_simple, X_test_simple, y_train_simple, y_test_simple = train_test_split(X_simple, y_simple, test_size=0.3, random_state=10)

regressor_simple = LinearRegression()
regressor_simple.fit(X_train_simple, y_train_simple)

y_pred_simple = regressor_simple.predict(X_test_simple)


print("\nSimple Linear Regression Evaluation:")
print(f"R2 score: {r2_score(y_test_simple, y_pred_simple)}")
print(f"MAE score: {mean_absolute_error(y_test_simple, y_pred_simple)}")
print(f"MSE score: {mean_squared_error(y_test_simple, y_pred_simple)}")

evaluate_simple = pd.DataFrame({'Actual': y_test_simple.values.flatten(), 'Predicted': y_pred_simple.flatten()})
print("\nComparison (Simple Linear Regression):")
print(evaluate_simple.head(10))
evaluate_simple.head(10).plot(kind='bar', figsize=(8, 5))
plt.title("Actual vs Predicted (Simple Linear Regression)")
plt.show()

X_multi = df[['Total Bilirubin', 'Direct Bilirubin', 'ALB Albumin']]
y_multi = df[['Result']]


X_train_multi, X_test_multi, y_train_multi, y_test_multi = train_test_split(X_multi, y_multi, test_size=0.3, random_state=10)

regressor_multi = LinearRegression()
regressor_multi.fit(X_train_multi, y_train_multi)

y_pred_multi = regressor_multi.predict(X_test_multi)


print("\nMultiple Linear Regression Evaluation:")
print(f"R2 score: {r2_score(y_test_multi, y_pred_multi)}")
print(f"MAE score: {mean_absolute_error(y_test_multi, y_pred_multi)}")
print(f"MSE score: {mean_squared_error(y_test_multi, y_pred_multi)}")

evaluate_multi = pd.DataFrame({'Actual': y_test_multi.values.flatten(), 'Predicted': y_pred_multi.flatten()})
print("\nComparison (Multiple Linear Regression):")
print(evaluate_multi.head(10))
evaluate_multi.head(10).plot(kind='bar', figsize=(8, 5))
plt.title("Actual vs Predicted (Multiple Linear Regression)")
plt.show()
# Out:
# Numeric Columns in Dataset:
# Index(['Age of the patient', 'Total Bilirubin', 'Direct Bilirubin',
#        'Alkphos Alkaline Phosphotase', 'Sgpt Alamine Aminotransferase',
#        'Sgot Aspartate Aminotransferase', 'Total Protiens', 'ALB Albumin',
#        'A/G Ratio Albumin and Globulin Ratio', 'Result'],
#       dtype='object')
# Simple Linear Regression Evaluation:
# R2 score: 0.05056060547502217
# MAE score: 0.3978290447676606
# MSE score: 0.19540787090572442
#
# Comparison (Simple Linear Regression):
#    Actual  Predicted
# 0       1   1.331346
# 1       2   1.327985
# 2       2   1.324625
# 3       1   1.327985
# 4       1   1.309501
# 5       1   1.306140
# 6       2   1.331346
# 7       1   1.292697
# 8       1   1.228841
# 9       1   1.265810
# Multiple Linear Regression Evaluation:
# R2 score: 0.07245004484128625
# MAE score: 0.390103111554872
# MSE score: 0.19090271895337502
#
# Comparison (Multiple Linear Regression):
#    Actual  Predicted
# 0       1   1.290287
# ...
